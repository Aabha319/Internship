# %%
# Python program to print all heading tags
import requests
from bs4 import BeautifulSoup
link = 'https://www.wikipedia.org/'
request = requests.get(link)
Soup = BeautifulSoup(request.text, 'lxml')
headingtags = ["h1", "h2", "h3","h4","h5","h6"]
for tags in Soup.find_all(headingtags):
    print(tags.name + ' -> ' + tags.text.strip())
# Out:
# h1 -> Wikipedia
#
# The Free Encyclopedia
# h2 -> 1 000 000+
#
#
# articles
# h2 -> 100 000+
#
#
# articles
# h2 -> 10 000+
#
#
# articles
# h2 -> 1 000+
#
#
# articles
# h2 -> 100+
#
#
# articles

# %%
import pandas as pd
import numpy as np

import requests
from requests import get
from bs4 import BeautifulSoup

from time import sleep
from random import randint
titles = []
years = []
imdb_ratings = []
pages = np.arange(1, 101, 50)
for page in pages:
    page = requests.get('https://www.imdb.com/search/title/?groups=top_100&ref_=adv_prv' + str(page) + '&ref_=adv_nxt',headers=headers)
    soup = BeautifulSoup(page.text, 'html.parser')
    movie_div = soup.find_all('div', class_='lister-item mode-advanced')
    sleep(randint(2,10))
    for container in movie_div:
        
        name = container.h3.a.text
        titles.append(name)
        
        year = container.h3.find('span', class_='lister-item-year').text
        years.append(year)
        
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)
        
movies = pd.DataFrame({'movie':titles,
                       'year':years,
                       'imdb_rating':imdb_ratings})

movies
# Out:
#                                              movie    year  imdb_rating
# 0                          Spider-Man: No Way Home  (2021)          8.7
# 1                         The Shawshank Redemption  (1994)          9.3
# 2                                  The Dark Knight  (2008)          9.0
# 3                                Avengers: Endgame  (2019)          8.4
# 4                                     Interstellar  (2014)          8.6
# ..                                             ...     ...          ...
# 95                                         Memento  (2000)          8.4
# 96  Star Wars: Episode V - The Empire Strikes Back  (1980)          8.7
# 97                                     The Shining  (1980)          8.4
# 98                  The Good, the Bad and the Ugly  (1966)          8.8
# 99                      Terminator 2: Judgment Day  (1991)          8.5
#
# [100 rows x 3 columns]
